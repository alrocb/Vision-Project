# %%
from header import *

# %%
tif_file = "/fhome/mapsiv/QuironHelico/WSI_Example/B22-31-HP.tiff"
extract_patches(tif_file)
# Out:
# The shape of your image is: (46080, 121856, 3)
# Resizing image...
# The new shape is: (460, 1218, 3)
# Practically we preserve all the aspect ratio when resizing since the original was: 2.6444444444444444 and the new one is: 2.6478260869565218
# Plotting image...
# Converting image from BGR to HSV...
# Extracting Hue channel...
# Canal extracted! Shape: (460, 1218, 1)
# Visualizing..
# Preparing to extract contours..
# Contorno detectado
# 0 211 244 236
# Contorno detectado
# 554 182 243 234
# Contorno detectado
# 1023 0 190 333
# Visualizing extracted contours..
# Printing crop number: 0
# Printing crop number: 1
# Printing crop number: 2
# Time to process the cropped images to extract patches..
# Extracting saturation channel from 0 crop...
# Binarizing image...
# Applying morphological operation to avoid holes and noise... (opening)
# Defining window for sliding window process..
# Got it! Patches obtained: 310
# Visualizing 5 first patches..
# ...
